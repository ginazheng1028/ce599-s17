# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('data/BARTEstimationFile.csv', parse_dates=['MONTH'], index_col='MONTH')
df.head()
# Out:
#                  RIDERS  STATIONS  CASH_FARE_2010USD_BART  \
# MONTH
# 2001-01-01  321180.5238        39                3.262745
# 2001-02-01  334885.1053        39                3.249754
# 2001-03-01  340021.5455        39                3.242376
# 2001-04-01  333794.4286        39                3.229546
# 2001-05-01  333847.4545        39                3.215007
#
#             AVG_FARE_2010USD_BART           HH      HH_0VEH          POP  \
# MONTH
# 2001-01-01               2.555435  1452556.571  187359.1429  3870692.571
# 2001-02-01               2.545259  1452696.413  187278.4921  3870052.746
# 2001-03-01               2.539481  1452836.254  187197.8413  3869412.921
# 2001-04-01               2.529432  1452976.095  187117.1905  3868773.095
# 2001-05-01               2.518045  1453115.937  187036.5397  3868133.270
#
#                 WORKERS  MEDIAN_HHINC_2010USD  SERVMILES_E_BART     ...       \
# MONTH                                                               ...
# ...

# %%
df[['RIDERS','CASH_FARE_2010USD_BART']].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11600e6a0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x116076898>], dtype=object)

# %%
fig = sm.graphics.tsa.plot_acf(df['RIDERS'], lags=176)

# %%
fig = sm.graphics.tsa.plot_acf(df['CASH_FARE_2010USD_BART'], lags=15)

# %%
 df['RIDERS_DIFF'] = df['RIDERS'] -  df['RIDERS'].shift(12)

# %%
mod = smf.ols('RIDERS_DIFF ~ CASH_FARE_2010USD_BART', data=df)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            RIDERS_DIFF   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     2.593
# Date:                Fri, 05 May 2017   Prob (F-statistic):              0.109
# Time:                        00:18:24   Log-Likelihood:                -1844.9
# No. Observations:                 163   AIC:                             3694.
# Df Residuals:                     161   BIC:                             3700.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept              -7.525e+04   5.13e+04     -1.466      0.145   -1.77e+05    2.61e+04
# ...
